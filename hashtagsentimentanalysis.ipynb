# %%
from IPython.display import Image

print("Hashtags obtained from negative tweets")
Image("Figure_3-4.png")
# Out:
# Hashtags obtained from negative tweets

# %%
print("Hashtags obtained from positive tweets")
Image("Figure_3-3.png")
# Out:
# Hashtags obtained from positive tweets
